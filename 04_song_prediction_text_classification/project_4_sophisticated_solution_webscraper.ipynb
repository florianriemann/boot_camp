# %% [markdown]
# # Import libraries

# %% [markdown]
# This programm was developed by Christoph Frost ...

# %%
import requests
import bs4
import os
import time
import re

# %% [markdown]
# # Define necessary functions

# %% [markdown]
# ## Does Website exists?

# %%
def existing_url(res):

    if res.status_code != 200: #if not 200, there is any error (server, host,...)
        return 'No lyrics'
    else:
        # if response is 200, do the soup
        soup = bs4.BeautifulSoup(res.text, 'lxml')
        soup_text = soup.select_one('div>hgroup>h2').text
        # already examined error text
        error_text = "We couldn't find any artists matching your query."
        print(soup_text)
        if soup_text.lower() == error_text.lower():
            return 'Page not exists'       
    
    return 'exists'

# %% [markdown]
# ## Duplicate handling

# %%
def duplicate_handling(res,title_links):
    soup = bs4.BeautifulSoup(res.text, 'lxml')
    song_select = soup.select('td.tal.qx>strong>a')
    print(len(song_select))
    
    for song in song_select:
        #1. Check ( and [ and split it:
        title = re.split('\s\(|\s\[|(\s|)[\?!]',song.text)[0].lower()
        #2. avoid duplicates by 
        if any(title in inner_list for inner_list in title_links) == False:
            link = song['href'].replace('/','',1)
            add_pair = [title,link]
            title_links.append(add_pair)
    
    return title_links

# %% [markdown]
# ## Download lyrics and save in folder

# %%
def download_save(newpath,url,title_links):
    mislead = 0
    download = 0
    for song in title_links[0:150]:
        time.sleep(1)
        lyric_url = url + song[1] # fragment of url
        response = requests.get(lyric_url)
        # do the soup
        soup = bs4.BeautifulSoup(response.text, 'lxml')
        try: # some songs that are not linked with lyrics
            lyric_text=soup.find('pre', {'id': 'lyric-body-text'}).text
        except AttributeError: # if the link actually doesn't contain lyrics
            print(f'Link of song {song[0]} does not lead to any lyrics!')
            mislead += 1
        else: 
            print(song[0])
            title = re.sub('[\W]','_',song[0]) # song[0] is title of the song
            print(title)

            if not os.path.exists(newpath):  # creates folder if necessary
                os.makedirs(newpath)
            with open(newpath +'/'+title + '.txt', 'w') as response_file:  # saves the lyric-files
                response_file.write(lyric_text)
            print(title_links.index(song))
            download+=1
    
    print(f'The number of misleading links: {mislead}')
    print(f'The number of downloaded files: {download}')
    print(f'The number of all tried songs: {len(title_links)}')

# %% [markdown]
# # Run the Scraping Program

# %%
url = 'https://www.lyrics.com/'
path = os.getcwd()
artist_sum = 0
while artist_sum < 2:
    title_links = []
    
    #0. Input-Assignemt for which Interpret
    artist = input('The lyrics of which artist you would like to scrape?')
    artist = artist.lower()
    artist_url = url + 'artist/' + artist
    print(artist_url)
    
    #request the URL
    res = requests.get(artist_url)
    print(res.status_code)
    #1.existing URL?
    exist = existing_url(res)
    print(exist)
    #Repeat-Condition
    if (exist == 'No lyrics') or exist == 'Page not exists':
        print(f'{artist} is not available. Please enter another artist.')
        continue    
    
    #2.duplicate handling: avoid '()' and '[]' and ignore doubles
    title_links = duplicate_handling(res,title_links) # creates a nested list (list of list [[a1,a2],[b1,b2],...])
    
    #3. check if more than 100 different songs
    if len(title_links) < 100:
        print(f'{artist} has just {len(title_links)} different songs instead 100. Please enter another artist.')
        continue
    else:
        print(f'{artist} has {len(title_links)} different songs. Congrats!')
    
    #4. download lyrics and save to an individual folder
    print(f'The lyrics of the {len(title_links)} songs of {artist} are going to be saved now.')
    newpath = path +'/'+ artist #for new folder
    download_save(newpath,url,title_links)
    
    artist_sum += 1
# Out:
# The lyrics of which artist you would like to scrape?Bob Marley
# https://www.lyrics.com/artist/bob marley
# 200
# Missing lyrics by Bob Marley?
# exists
# 10142
# bob marley has 343 different songs. Congrats!
# The lyrics of the 343 songs of bob marley are going to be saved now.
# easy skanking
# easy_skanking
# 0
# concrete jungle
# concrete_jungle
# 1
# slave driver
# slave_driver
# 2
# stop the train
# stop_the_train
# 3
# Link of song baby we've got a date does not lead to any lyrics!
# stir it up
# stir_it_up
# 5
# Link of song kinky reggae does not lead to any lyrics!
# no more trouble
# no_more_trouble
# 7
# there she goes
# there_she_goes
# 8
# put it on
# put_it_on
# 9
# my jamaican guy
# my_jamaican_guy
# 10
# jamming
# jamming
# 11
# soul shakedown party
# soul_shakedown_party
# 12
# do it twice
# do_it_twice
# 13
# Link of song sun is shining does not lead to any lyrics!
# natural mystic
# natural_mystic
# 15
# lively up yourself
# lively_up_yourself
# 16
# soul rebel
# soul_rebel
# 17
# it's alright
# it_s_alright
# 18
# no sympathy
# no_sympathy
# 19
# Link of song my cup does not lead to any lyrics!
# reaction
# reaction
# 21
# kaya
# kaya
# 22
# Link of song trench town rock does not lead to any lyrics!
# mr. brown
# mr__brown
# 24
# Link of song rainbow country does not lead to any lyrics!
# positive vibration
# positive_vibration
# 26
# wake up and live
# wake_up_and_live
# 27
# them belly full
# them_belly_full
# 28
# africa unite
# africa_unite
# 29
# Link of song zimbabwe does not lead to any lyrics!
# Link of song get up stand up does not lead to any lyrics!
# exodus
# exodus
# 32
# the heathen
# the_heathen
# 33
# bend down low
# bend_down_low
# 34
# burnin' & lootin'
# burnin____lootin_
# 35
# one love
# one_love
# 36
# love and affection
# love_and_affection
# 37
# Link of song mega dog does not lead to any lyrics!
# Link of song it hurts to be alone does not lead to any lyrics!
# who feels it
# who_feels_it
# 40
# Link of song dancing shoes does not lead to any lyrics!
# sugar sugar
# sugar_sugar
# 42
# mellow mood
# mellow_mood
# 43
# nice time
# nice_time
# 44
# how many times
# how_many_times
# 45
# keep on moving
# keep_on_moving
# 46
# Link of song african herbsman does not lead to any lyrics!
# stop that train
# stop_that_train
# 48
# don't rock my boat
# don_t_rock_my_boat
# 49
# brain washing
# brain_washing
# 50
# soul almighty
# soul_almighty
# 51
# riding high
# riding_high
# 52
# rebel's hop
# rebel_s_hop
# 53
# try me
# try_me
# 54
# Link of song the sun is shining does not lead to any lyrics!
# touch me
# touch_me
# 56
# Link of song go tell it on the mountain does not lead to any lyrics!
# can't you see
# can_t_you_see
# 58
# hammer
# hammer
# 59
# Link of song stand alone does not lead to any lyrics!
# all in one
# all_in_one
# 61
# cheer up
# cheer_up
# 62
# soul captives
# soul_captives
# 63
# small axe
# small_axe
# 64
# 400 years
# 400_years
# 65
# Link of song corner stone does not lead to any lyrics!
# no water
# no_water
# 67
# chances are
# chances_are
# 68
# caution
# caution
# 69
# soon come
# soon_come
# 70
# back out
# back_out
# 71
# duppy conqueror
# duppy_conqueror
# 72
# hypocrites
# hypocrites
# 73
# thank you lord
# thank_you_lord
# 74
# mr. chatterbox
# mr__chatterbox
# 75
# natty dread
# natty_dread
# 76
# so jah seh
# so_jah_seh
# 77
# no woman no cry
# no_woman_no_cry
# 78
# guava jelly
# guava_jelly
# 79
# i shot the sheriff
# i_shot_the_sheriff
# 80
# Link of song zion train does not lead to any lyrics!
# Link of song crazy baldhead does not lead to any lyrics!
# is this love
# is_this_love
# 83
# Link of song running away does not lead to any lyrics!
# johnny was
# johnny_was
# 85
# Link of song could you be loved does not lead to any lyrics!
# Link of song waiting in vain does not lead to any lyrics!
# three little birds
# three_little_birds
# 88
# Link of song war does not lead to any lyrics!
# mellow moods
# mellow_moods
# 90
# roots, rock, reggae
# roots__rock__reggae
# 91
# who the cap fit
# who_the_cap_fit
# 92
# night shift
# night_shift
# 93
# Link of song rat race does not lead to any lyrics!
# one love/people get ready
# one_love_people_get_ready
# 95
# satisfy my soul
# satisfy_my_soul
# 96
# she's gone
# she_s_gone
# 97
# crisis
# crisis
# 98
# time will tell
# time_will_tell
# 99
# Link of song so much trouble in the world does not lead to any lyrics!
# survival
# survival
# 101
# Link of song one drop does not lead to any lyrics!
# ride natty ride
# ride_natty_ride
# 103
# ambush in the night
# ambush_in_the_night
# 104
# bad card
# bad_card
# 105
# work
# work
# 106
# pimper's paradise
# pimper_s_paradise
# 107
# redemption song
# redemption_song
# 108
# Link of song fussing and fighting does not lead to any lyrics!
# memphis
# memphis
# 110
# get up, stand up
# get_up__stand_up
# 111
# punky reggae party
# punky_reggae_party
# 112
# Link of song buffalo soldier does not lead to any lyrics!
# Link of song fussin' & fightin' does not lead to any lyrics!
# redder than red
# redder_than_red
# 115
# judge not
# judge_not
# 116
# Link of song roots rock reggae does not lead to any lyrics!
# Link of song simmer down does not lead to any lyrics!
# don’t rock my boat
# don_t_rock_my_boat
# 119
# Link of song (gotta) keep on moving does not lead to any lyrics!
# keep on movin'
# keep_on_movin_
# 121
# soul rebels
# soul_rebels
# 122
# babylon system
# babylon_system
# 123
# marley chant/natural mystic
# marley_chant_natural_mystic
# 124
# oh, carolina
# oh__carolina
# 125
# Link of song greetings does not lead to any lyrics!
# i know a place
# i_know_a_place
# 127
# who colt the game
# who_colt_the_game
# 128
# Link of song burnin' lootin' does not lead to any lyrics!
# war/no more trouble
# war_no_more_trouble
# 130
# coming in from the cold
# coming_in_from_the_cold
# 131
# you can't blame the youth
# you_can_t_blame_the_youth
# 132
# rastaman chant
# rastaman_chant
# 133
# turn your lights down low
# turn_your_lights_down_low
# 134
# Link of song jammin' does not lead to any lyrics!
# high tide or low tide
# high_tide_or_low_tide
# 136
# trenchtown rock
# trenchtown_rock
# 137
# i am going home
# i_am_going_home
# 138
# let him go
# let_him_go
# 139
# Link of song maga dog does not lead to any lyrics!
# i'm still waiting
# i_m_still_waiting
# 141
# Link of song lonesome feeling does not lead to any lyrics!
# wings of a dove
# wings_of_a_dove
# 143
# Link of song to be young gifted and black does not lead to any lyrics!
# don't rock the boat
# don_t_rock_the_boat
# 145
# Link of song fussing & fighting does not lead to any lyrics!
# treat you right
# treat_you_right
# 147
# Link of song fussin' and fightin' does not lead to any lyrics!
# Link of song donna does not lead to any lyrics!
# The number of misleading links: 40
# The number of downloaded files: 110
# The number of all tried songs: 343

# %%
output = set()
for x in title_links:
    output.add(x[0])
print(output)
len(output)
# Out:
# {'everyboyd', 'my beautiful woman', 'as long as you love me', "we've got it goin' on", "it's christmas time again", 'shape of my heart', "it's gotta be you", 'you can let go', 'nobody else', "darlin'", 'new love', 'all i have to give, pt. 2', 'ok', 'got to get it', 'rebel', "that's the way i like it", "she's a dream", 'time', "quit playin' games", 'love somebody', 'i need you tonight / heaven in your eyes', 'aurora', 'make believe', 'pda', 'set adrift on memory bliss', "what's going on", 'shape of the heart', 'the one', 'how did i fall in love with you', "let's make a toast to our love", 'matches', 'on without you', 'try', 'quit playing games', 'where can we go from here', "you're the reason", 'the way it is', "i'll never brak your heart", 'lay down beside me', 'let it be me', 'song for the unloved', 'permanent stain', 'no goodbyes', 'sexbomb', 'crawling back to you', 'one phone call', "movin' on", 'treat me right', 'shoe me the meaning of being lonely', 'hey, mr, dj', "don't try this at home", 'breathe', '10,000 promises', 'cinderella', 'i promise you', 'let me see you squirrel', 'no one else comes close', 'missing you', 'yes i will', 'answer to our life', "i'll never break your heart", 'how do i live', 'nowhere to go', 'satellite', 'i want it that way', 'best days', 'passionate', 'somebody that i used to know', 'get down', "don't gobreaking my heart", 'if you want it to be good girl', 'roll with it', '10, 000 promises', "that's what she said", 'if you knew what i knew', 'last night you saved my life', 'all of your life', 'everyone', 'inconsolable', "let's have a party", 'helpless when she smiles', 'madeleine', 'soldier', 'the call', "i'll never break your hearts", 'i need you tongiht', "don't leave me", 'who do you love', 'said i love you', 'christmas time', "let's take a lifetime", 'masquerade', "don't disturb this groove", 'not for me', 'in a world like this', 'incomplete', 'the way it was', 'something that i already know', 'do you remember', "don't wanna lose you now", 'the answer to our life', 'the perfect fan', 'feels like home', 'boys will be boys', "don't go breaking my heart", "can't fight this feeling", 'one in a million', 'you wrote the book on love', 'bigger', 'funny face', 'call', 'trouble is', 'never gone', 'hey, mr.dj', 'if you stay', 'all i have to give', 'sick as my secrects', 'any other way', 'one', 'everytime i close my eyes', "we've got it going on", 'i still', 'shining star', 'no place', 'bye bye love', 'i wanna be with you', 'shattered', 'just want you to know', "i'll never find someone like you", 'downpour', "tell me that i'm dreaming", 'in christ alone', 'un-break my heart', "liftin' me up", 'my heart stays with you', 'in pieces', 'non puoi lasciarmi cosi', 'close my eyes', "there's us", 'undone', 'i need you tonight', 'hologram', 'in your arms', "it's true", 'young girls', 'show me the meaning', "don't want you back", 'every time i close my eyes', "we've got it goin on", '10000 promises', "show 'em", 'rush over me', 'by my side', 'anywhere for you', 'panic', 'intro', 'hey mr dj', 'if i knew then', 'show me the meaning of being lonely', 'trust me', 'the best that i can', 'lose it all', 'everybody', 'unsuspecting sunday afternoon', 'chateau', "ain't nobody", 'like a child', 'just like you like it', 'team', 'drowning', 'chances', 'get another boyfriend', 'unmistakable', 'helpless', 'climbing the walls', 'over her', 'just to be close to you', 'give me your heart', 'hey, mr. dj', 'larger than life', 'as long as you love them', 'god, your mama, and me', 'i still...', 'this is us', 'fallen angel', "if i don't have you", '...baby one more time', "that's the way", 'siberia', 'i gotta feeling', 'party shot', 'love knows i love you', 'hey mr. dj', 'i never break your heart', "i'll be there for you", 'shout', 'straight through my heart', 'nobody but you', 'i still-', 'poster girl', 'children need a helping hand', 'back to your heart', 'nunca te hare llorar', 'safest place to hide', 'is it just me', 'weird world', ...
# 214
